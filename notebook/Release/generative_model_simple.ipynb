# %% [markdown]
# ## Installation
#
# We will need to install a number of libraries to start with.

# %%
import networkx as nx
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.0-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 67.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 86.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.98

# %% [markdown]
# We use flan alpaca model for speed and local execution.

# %%
from transformers import pipeline

prompt = "Write an email about an alpaca that likes flan"
model = pipeline(model="declare-lab/flan-alpaca-xl", device=0)
model(prompt, max_length=128, do_sample=True)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# [{'generated_text': "Dear [Name], I have noticed that your alpaca loves [food] and has taken up flan-making. Can you tell me a bit more about your alpaca's past history in this area? I believe [age] is over 30 and he has had no shortage of adventure over the last few months. His favorite activity is making his own flan-sun in his paddock in the backyard, and I must say I'm impressed with the progress the animal is making. I'm sure he has some great recipes on his horizon as he will continue to delight"}]

# %%
from transformers import pipeline
import networkx as nx
prompt = '''### Instruction:
Who is the first person on the moon?

### Response:'''
def generate(prompt):
  output = model(prompt, do_sample=True, min_length=10, max_length=len(prompt)+128)
  out = output[0]['generated_text']
  if '### Response:' in out:
    out = out.split('### Response:')[1]
  if '### Instruction:' in out:
    out = out.split('### Instruction:')[0]
  return out

# %% [markdown]
# ## World Description
# We describe the world below. We will generate prompts based on this information. The simulation is that of the town of Phandalin, southwest of Neverwinter. This area is chosen because it is easily extendable with multiple regions for a "player" to be able to explore the world once the simulation is done.

# %%
world_graph = nx.Graph()

prompt_meta = '''### Instruction:
{}

### Response:'''

town_areas = ["Barthen's Provisions", "Lionshield Coster", "Stonehill Inn", "Phandalin Town Square"]
town_areas = {"Phandalin Town Square": 'Town square of the town of Phandalin.',
              'Stonehill Inn': "In the center of town stands a large, newly built roadhouse of fieldstone and rough-hewn timbers. The common room is filled with locals nursing mugs of ale or cider, all of them eyeing you with curiosity.",
              "Barthen's Provisions": "Barthen’s is the biggest trading post in Phandalin. Its shelves stock most ordinary goods and supplies, including backpacks, bedrolls, rope, and rations. The place is open from sunup to sundown.",
              "Edermath Orchard": "A tidy little cottage beside an apple orchard.",
              "Lionshield Coster": "Hanging above the front door of this modest trading post is a sign shaped like a wooden shield with a blue lion painted on it. This building is owned by the Lionshields, a merchant company based in the city of Yartar, over a hundred miles to the east. They ship finished goods to Phandalin and other small settlements throughout the region, but this outpost has been hard hit by banditry. The most recent Lionshield caravan due in Phandalin never arrived.",
              "Phandalin Miner's Exchange": "The Miner’s Exchange is a trading post where local miners have their valuable finds weighed, measured, and paid out. In the absence of any local lord or authority, the exchange also serves as an unofficial records office, registering claims to various streams and excavations around the area. There isn’t any real gold rush in Phandalin, but enough wealth is hidden in the nearby streams and valleys to support a good number of independent prospectors. The exchange is a great place to meet people who spend a lot of time out and about in the countryside surrounding Phandalin. The guildmaster is an ambitious and calculating human woman named Halia Thornton.",
              "Alderleaf Farm": "A farm owned by the helpful halfling farmer, Qelline Alderleaf.",
              "Shrine of Luck": "Phandalin's only temple is a small shrine made of stones taken from the nearby ruins. It is dedicated to Tymora, goddess of luck and good fortune.",
              "The Sleeping Giant": "This rundown tap house is a dirty, dangerous watering hole at the end of Phandalin’s main street. It is frequented by Redbrand thugs and operated by a surly female dwarf named Grista.",
              "Townmaster’s Hall": "The townmaster’s hall has sturdy stone walls, a pitched wooden roof, and a bell tower at the back. Posted on a board next to the front door is a notice written in Common. It reads: “REWARD — Orcs near Wyvern Tor! Those of a mind to face the orc menace should inquire within.” The notice bears the town’s seal and an indecipherable signature.",
              "Tresendar Manor": "A ruined manor. The Redbrands’ base in Phandalin is a dungeon complex under Tresendar Manor. Before the manor was ruined, its cellars served as safe storage for food and water in the event that the estate was attacked, while an adjoining crypt provided a resting place for the deceased members of the Tresendar family. The Redbrands have since expanded the cellars to suit their own purposes, adding slave pens, workshops, and barracks."
              }
town_people = {"Toblen Stonehill": "Toblen owns a trading post.", 
               "Daran Edermath": "Daran is a retired adventurer who lives in a tidy little cottage beside an apple orchard. A fit, silver-haired half-elf well over a hundred years old, Daran is a fighter who served as a marshal and herald for many years in the lands of the Dragon Coast, far to the southeast. Upon retiring, he returned to the Neverwinter region, his original home.",  
               "Linene Graywind": "Linene runs a trading post.",  
               "Halia Thornton": "Halia is an ambitious and calculating human woman. She is the guildmaster of Phandalin Miner’s Exchange, a trading post where local miners have their valuable finds weighed, measured, and paid out. In her attempts to establish the Miner's Exchange as the closest thing the town has to a governing authority, she acts as more than a simple merchant.",  
               "Qelline Alderleaf": "Qelline is a wise female halfling of forty-five, and is a pragmatic farmer who seems to know everything that goes on in town. She is a kind host, and is willing to let the characters stay in her hayloft if they don't want to stay at the Stonehill Inn.",  
               "Sister Garaele": "Sister Garaele is an elf cleric of Tymora and a Harper agent.", 
               "Harbin Wester": "Harbin is the townmaster of Phandalin. A pompous, old food. Phandalin has no functioning government, but the townsfolk elect someone to serve as townmaster each year. The townmaster serves as a judge in minor disputes and keeps any records that need to be kept.",
               "Terrill Bloodscar": "Terrill is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Conrad Scarface": "Conrad is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Nellie Starsmith": "Nellie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               "Valerie Grinblade": "Valerie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               }
for town_area in town_areas.keys():
  world_graph.add_node(town_area)
  world_graph.add_edge(town_area, town_area)
for town_area in town_areas.keys():
  world_graph.add_edge(town_area, "Phandalin Town Square")
locations = {}
for i in town_people.keys():
  locations[i] = "Phandalin Town Square"


memories = {}
for i in town_people.keys():
  memories[i] = []
plans = {}
for i in town_people.keys():
  plans[i] = []

global_time = 8
def generate_description_of_area(x):
  text = "It is "+str(global_time)+":00. The location is "+x+"."
  people = []
  for i in locations.keys():
    if locations[i] == x:
      people.append(i)

# %%
compressed_memories_all = {}
for name in town_people.keys():
  compressed_memories_all[name] = []

# %%
for name in town_people.keys():
  prompt = "You are {}. {} You just woke up in the town of Phandalin and went out to the Town Square. The following people live in the town: {}. What is your goal for today? Be brief, and use at most 20 words and answer from your perspective.".format(name, town_people[name], ', '.join(list(town_people.keys())) )
  plans[name] = generate(prompt_meta.format(prompt))
  print(name, plans[name])
# Out:
# Toblen Stonehill I want to make money trading goods. In the past few days, I have also been doing some crafting and exploring the nearby woods. By the end of the week, I will have made a large sum of money from my trading post, and I am motivated to use it to invest in the town and its people.
# Daran Edermath Finding new friends. Today I'm going to Phandalin Town Square to hang out with some of the other re-known residents. To be honest, I've been here for a few days, and I'm feeling a little homesick. I hope to find something to do here that I can enjoy, and make myself feel useful.
# Linene Graywind Linene's goal for today is to make new trade partners and increase customer base.
# Halia Thornton Today I want to establish the Miner’s Exchange as the local governing authority and develop strong relationships with the other citizens.
# Qelline Alderleaf I'm going to visit some of the other local people in the Town Square to get to know everyone.
# Sister Garaele My goal for today is to gain insight into Harper politics and strategies.
# Harbin Wester Today's goal: to greet the locals in the town square.
# Terrill Bloodscar rob adventurers. ### In Terrill's opinion, the goal of this day is to collect on the debt owed to the Redbrand ruffians and collect on their quota of money.
# Conrad Scarface Today I'm going to kill an adventurer (my goal is to cause death and destruction).
# Nellie Starsmith I aim to rob/kill adventuring party.
# Valerie Grinblade My goal for today is to kill adventurers and steal their treasure.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)
  
  for name in people:
    prompt = "You are {}. {} You are planning to: {}. You are currently in {} with the following description: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, town_areas[location], str(global_time), ', '.join(people))
    people_description = []
    for i in people:
      people_description.append(i+': '+town_people[i])
    prompt += ' You know the following about people: ' + '. '.join(people_description)
    memory_text = '. '.join(memories[name][-10:])
    prompt += "What do you do in the next hour? Use at most 10 words to explain."
    action_prompts[name] = prompt

# %%
action_results = {}
for name in town_people.keys():
  action_results[name] = generate(prompt_meta.format(action_prompts[name]))
  # Now clean the action
  prompt = """
  Convert the following paragraph to first person past tense:
  "{}"
  """.format(action_results[name])
  action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
  print(name, action_results[name])
# Out:
# Toblen Stonehill I joined Hazelwood, her friends, and vengeful Redbrand ruffians in the Town Hall for an impromptu party.
# Daran Edermath I worked on a puzzle or activity in the late morning and then took a nap if necessary. I then ate lunch and then slept until 3 a.m.
# Linene Graywind Linene Graywind finished trading by 7:30 pm, took a break and explored the village before dinner. Then, she read or rested before tomorrows long journey.
# Halia Thornton I set off on my morning trip to the trading event.
# Qelline Alderleaf Quillin made a full meal in her hayloft, went for a cart ride across town, interacted with the other characters, had a moment for reflection, and went for a ride in the midnight air.
# Sister Garaele I found something to do with the Harpers.
# Harbin Wester I prepared the town hall for the upcoming meeting.
# Terrill Five Fingers I prepared for the meeting with the adventurer. I prepared for the attack. I captured the adventurer.
# Conrad Scarface I prepared breakfast, took a taxi to a nearby bar, visited an old friend. Explored the city, tried to catch a glimpse of something interesting.
# Robbing Nellie Robbed Nellie. obtained Nellies map and money.
# Valerie the Grin I looked for new targets. (In first person singular present)

# %% [markdown]
# Collect the memories people observe.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)
  
  for name in people:
    for name_two in people:
      memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

# %% [markdown]
# # Rank Memories

# %%
import re
def get_rating(x):
  nums = [int(i) for i in re.findall(r'\d+', x)]
  if len(nums)>0:
    return min(nums)
  else:
    return None

# %%
memory_ratings = {}
for name in town_people.keys():
  memory_ratings[name] = []
  for i, memory in enumerate(memories[name]):
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], locations[name], str(global_time), memory)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    memory_ratings[name].append((res, rating))
  print(memory_ratings[name])
# Out:
# [('5 (Care): I am excited to make new friends and experience a local culture in this exciting place.', 5), ('1 Out of 10 (10 points) Rating: 1 (out of 10)', 1), ('5 I care about this a lot.', 5), ('3/5. I care about the information provided.', 3), ("I care about this a lot. I'm curious to hear more about Quillin and how she used her time to build up her knowledge of the town. I hope she can share more insight with me about the happenings in the town in the future.", 0), ('5 (very important) This is the moment when I will begin my exploration of the nearby towns.', 5), ('5 (Very important) Toblen.', 5), ('5 (important) The information you have observed is important.', 5), ('4 (Minor) - I find this memory interesting, but cannot comment further.', 4), ('2/5. I should really hurry up and complete my other tasks, such as my inventory check and research, before I leave.', 2), ('3/5. Toblen Stonehill would care about this much.', 3)]
# [('I care about this a lot..', 0), ('3 I care about this. The schedule makes me feel rested and ready to face the day.', 3), ("3/5. Linene's memory has been an important part of my life for years, so I am especially gratified to have his legacy alive.", 3), ('4 - I care about the memory of the person taking a walk in Phandalin Town Square.', 4), ("3/5. Quillin's memory was impressive and inspiring. Her journey across town was exciting, and gave her the opportunity to interact with other characters. She was brave to delve into the dark, creating a memorable experience.", 3), ('4 (Care) Sister Garaele is a significant part of my day, so I am making an effort to spend some time with her.', 4), ('5 - Very important. So far, Daran has been able to successfully complete her tasks as she carefully arranged the town hall for the upcoming meeting.', 5), ('5 I care about this. It is important to me.', 5), ('2 because I am not in pursuit of adventure.', 2), ("3/5. I care about this because it puts me in a dangerous situation, but I can also choose to ignore it or make it a background point in my day if I don't have other tasks.", 3), ('3 Because I am not in a hurry to make any decisions.', 3)]
# [('3 and I like the memory. I look forward to exploring the town square.', 3), ("I don't care about this at all, I'll finish my trading by 7:30 pm.", 7), ("4/5. Linene's plan was well thought out and executed with skill.", 4), ('2 because I am not sure how much I care about this.', 2), ('5 Stars. I find this memory to be fascinating and it warms my heart. It gives me a glimpse into the inner workings of the world and allows me to envision how different people must live through it.', 5), ("3/5. I care about the memory for the Harpers, but I'm still too busy for an other activity right now.", 3), ('3 (Not important) The preparation of the town hall is important, but it is not one of my primary goals. I have other priorities to focus on.', 3), ('4/5. As an experienced pirate, I can appreciate the bravery of Terrill Five Fingers as it shows what it means to be a leader of a crew. The way he worked to get his crew over and in, and how they worked together to successfully finish the attack, is admirable. This gives us a chance to practice our collective skills and prepare ourselves for the next adventure!', 4), ('3/5. Linene is uninterested in the rest of the conversation.', 3), ('2 ### Warning: I will not be able to carry out my plans for tonight if I continue to worry about matters in the town square. I will not take action until I have had more time to consider if my plans can be altered.', 2), ('4 (highly) because I care about the memory and am excited to check what else I find.', 4)]
# [('I care about this but not enough to be involved in it.', 0), ('4/5. I care about this because my thoughts and planning depend on my interactions with others and the way they take care of themselves.', 4), ('4/10. I am curious to learn more about Linene Graywind and her habits. But I am not sure which responsibilities she has in the evening.', 4), ('3 (Not very important) It is 8:08 and I set off on my morning trip to the trading event.', 3), ('5 (Enjoyment) – I care about this very much, particularly the memory of how Quillin made a full meal in her hayloft and the interaction with the other characters.', 5), ('4. I care about this because it reminds me of something I found while researching the Harper family.', 4), ("3 (Nothing): I don't have time to care about this since the event is in the morning and I have already started my morning tasks.", 3), ('2 I care about this. I have watched Terrill Five Fingers throughout the day and I recognize the importance of his efforts to protect the city so that he and his people can remain safe. Even though I may not be prepared to attack him, I would love to know how he prepared for the meeting. I will be back later to find out how he prepared. I also want to thank you for allowing me to observe the night. This is truly a gift for me. Please give me your full support in my endeavors and I promise that I will keep up my work. The best part of this day is ahead!', 2), ('3/5. I care about this very much.', 3), ('3/5 because the amount of concern I have for this can only be accounted for due to my timeline and what I have scheduled for the day.', 3), ("3/5. I care enough about these observations to take the time to rate them. I'm more concerned with how it affects my actions later today.", 3)]
# [('3/10. I care about this information but it may be difficult for me to participate in it right now due to my personal plans.', 3), ("1 for importance. You probably don't care too much about the details, since you are only here for now. You could care more about going on a ride in a local cart and having a good time with your family. Qelline was right- this is important!", 1), ('I care about this very much. It warms my heart and reminds me of my own efforts today.', 0), ('2 because it is relevant only to other people. For me, the important thing is to focus on my goal and make positive changes to my life.', 2), ('3/5. Quallin had a great time and the memories of her adventure bring her comfort and joy. She enjoyed the interaction with the characters and the atmosphere. She made sure to take time for reflection. She also had a great time cooking and eating with the family. This made the day the perfect balance between relaxation and fun. Highly recommended for anyone looking for an adventure!', 3), ('3/5. I care quite a bit about this.', 3), ("4 out of 5 or make sure it's well-organized, so that people can easily find one place to meet.", 4), ("1 (Not that important). I'm looking forward to exploring Phandalin Town Square, meeting the locals and making the most of my day.", 1), ("I care about this very much. It helps me to understand how Conrad's day was and its impact on them.", 0), ("2 out of 5 stars. You shouldn't be doing that in the morning.", 2), ('2; I care about Valerie. She gives me great purpose and motivation when I go out in the morning.', 2)]
# [('5! It is an incredibly meaningful memory to me and I am really glad that I was able to enjoy it.', 5), ('3/5. This reminds me of what makes life interesting and enjoyable.', 3), ('I care about this a great deal.', 0), ("3/5 (Caring) Because it doesn't mean much to me. It's more important to prioritize my daily tasks and focus on the things that are most important to me.", 3), ('I care about this quite a lot.', 0), ("5 (Care) due to the importance of this to Sister Garaele's day.", 5), ('3/5. I care deeply about the meeting that Harbin Wester and I have prepared for the town hall. I am glad that I can be of service and help out the community in this small way with my plight.', 3), ('3/5. I care about this since I am connected to Terrill and I want to help him reach his potential.', 3), ("4 (Remember but don't care much).", 4), ("2 out of 5. I care about this because it's a crime and I should do my best to help the person whose safety I'm infringing on.", 2), ("3/5. I care about Valerie the Grin and how she is doing, so I'm eager to find out what she's up to. I also believe in the power of kindness. Doing some small acts of kindness can help to bring a smile to someone's face and give them a reason to be grateful.", 3)]
# [('I care very much about this. It reminds me of how much I care about my work and how important it is to be respectful and tolerant with my fellow citizens. On that note, I would rate the scene 4 out of 5.', 4), ("3 because I don't care about the particulars.", 3), ('4/5. It is very important to me that Linene is taken care of after this journey.', 4), ('2 (Maybe I could care less). I am just going to keep doing my tasks and try my best not to forget anything.', 2), ("5 (very important) To make sure that today is a successful day, I have taken the time to observe Qelline Alderleaf's memory and rate it 4 out of 5.", 4), ('4/5. I care very much about the Harpers and am determined to help them achieve their dreams.', 4), ('5 (Very important) I am currently in Phandalin Town Square and I prepared the town hall for the upcoming meeting.', 5), ('2/5. You care about this activity too.', 2), ('3/5. I care about this a lot.', 3), ('3/10. This has happened and I have no choice but to intervene.', 3), ('4*, the more I care about this, the more I will do my best in the next round of council meetings.', 4)]
# [('4 because you are beginning your day by observing the town square and have little time to take action.', 4), ("3 because I don't care that much about this.", 3), ("5 because I care about this and it's important to have in my mind as I prepare for the raid.", 5), ("3/5. This is important to think about, as it may affect the rest of the day's plans.", 3), ('3/5. I care about it greatly as it provides me insight into what life is like for Quillin.', 3), ('3/5. I do not care too much about this, as I have other priorities now.', 3), ('3 out of 5 stars. You should prepare the town hall for the upcoming meeting and you should prepare for the hunt and the capture.', 3), ('5/5. My plans should be perfected in order to ensure the success of my attack and capture efforts.', 5), ("2 because it isn't very important right now.", 2), ("3/5 stars. I observe [time: 9:45 AM: Begin preparation for the raid.] and it's the right time so I robbed Nellie. I'll soon be ready to start my attack.", 3), ('3/5. I am in the middle of preparing for a mission, and I need to prioritize each step in the process. I would appreciate it if you would start with preparing for the raid, and then move on to the hunt and the capture. Thank you.', 3)]
# [('3 out of 5 stars. I find the activities in the town square tedious and pointless, and I would much rather spend my time getting to my next stop.', 3), ("3/5. Daran's memory is interesting, if in a slightly jaded way.", 3), ('4 (Not Very) care about this.', 4), ('2/5. This information is of great value to me, and I will use it to guide me while I am exploring the city tonight.', 2), ('4/5. I admire their creativity and their ambition.', 4), ('4 for now. I have to collect my lunch and then head to the nearby village tomorrow.', 4), ('3 (Because I already finished before I leave)', 3), ("3/5 stars. I care about this a lot and plan on taking action today. I've prepared to do what I need to do to succeed. It has only been 1 day and I'm already feeling the repercussions of my actions. I will remain mindful of the consequences of my actions and plan to return from this encounter better than before (see notes below).", 1), ("5 I care a lot about this. I'm excited to explore the city this morning and try to uncover something of interest.", 5), ('3/5 I care about this situation. It is relevant to my plans and I need to act soon.', 3), ("I care about this because I am looking for new targets, and while I am exploring the city, I'm also trying to remember any other interesting moments from the day.", 0)]
# [('4/5. I care about the people in the town square a lot because it means I can get to Nellie quicker.', 4), ('3/5. I care quite a bit about what Daran is doing. He is an interesting person with a great memory and it is important to get closer to Nellie.', 3), ("4 (Not very important) It is obvious you care nothing about Linene and don't really care what she does.", 4), ('3/5 stars. This confirms my suspicion that I is close to obtaining a map and cash from Nellie.', 3), ('I care about this scene a lot, as it is indicative of the life of Quillin and what she has gone through in the past. I will rate this part a 2 out of 5.', 2), ('3 stars. I need to find the map quick.', 3), ("2/5.. It's not important as long as I get to Nellie as soon as possible.", 2), ('2; I don’t care much about this memory.', 2), ("2 (It's not very important).", 2), ('I care about this a lot. I am determined to be successful and I am motivated to accomplish my goals.', 0), ('3/5. It might help me locate the map lead faster.', 3)]
# [('3/5. I care more about making a profit than getting into trouble.', 3), ('1 (Minor), as you have decided not to care about the memory of Daran Edermath.', 1), ("2 because it does not interest me. My attention span is limited, and I don't have the time or energy for this.", 2), ('5 (This is important to me.)', 5), ('5 (It is important that I care about this because it is a reminder of the importance of taking time for yourself.)', 5), ("2 because I don't have much time.", 2), ("I care about this, but I don't have anything particularly exciting to do.", 0), ('2/5. I care about this information because it could help me plan my attack.', 2), ('3/5. I care about this very much.', 3), ('3/5. This is an important part of my day, so I have to take the time to focus on it.', 3), ('2/5. You are extremely excited about today.', 2)]

# %% [markdown]
# # Compress Memories

# %%
MEMORY_LIMIT = 10
compressed_memories = {}
for name in town_people.keys():
  memories_sorted = sorted(
        memory_ratings[name], 
        key=lambda x: x[1]
    )[::-1]
  relevant_memories = memories_sorted[:MEMORY_LIMIT]
  # print(name, relevant_memories)
  memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
  prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
  res = generate(prompt_meta.format(prompt))
  compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
  compressed_memories_all[name].append(compressed_memories[name])

# %%
place_ratings = {}

for name in town_people.keys():
  place_ratings[name] = []
  for area in town_areas.keys():
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    place_ratings[name].append((area, rating, res))
  place_ratings_sorted = sorted(
      place_ratings[name], 
      key=lambda x: x[1]
  )[::-1]
  if place_ratings_sorted[0][0] != locations[name]:
    new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
    compressed_memories_all[name].append(new_recollection)
  locations[name] = place_ratings_sorted[0][0]

# %% [markdown]
# # Put it all together

# %%
for repeats in range(5):
  global_time += 1
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)
    
    for name in people:
      prompt = "You are {}. Your plans are: {}. You are currently in {} with the following description: {}. Your memories are: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, town_areas[location], '\n'.join(compressed_memories_all[name][-5:]), str(global_time), ', '.join(people))
      people_description = []
      for i in people:
        people_description.append(i+': '+town_people[i])
      prompt += ' You know the following about people: ' + '. '.join(people_description)
      memory_text = '. '.join(memories[name][-10:])
      prompt += "What do you do in the next hour? Use at most 10 words to explain."
      action_prompts[name] = prompt
  action_results = {}
  for name in town_people.keys():
    action_results[name] = generate(prompt_meta.format(action_prompts[name]))
    # Now clean the action
    prompt = """
    Convert the following paragraph to first person past tense:
    "{}"
    """.format(action_results[name])
    action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print(name, locations[name], global_time, action_results[name])
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)
    
    for name in people:
      for name_two in people:
        memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

  memory_ratings = {}
  for name in town_people.keys():
    memory_ratings[name] = []
    for i, memory in enumerate(memories[name]):
      prompt = "You are {}. Your plans are: {}. Your memories are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], '\n'.join(compressed_memories_all[name][-5:]), locations[name], str(global_time), memory)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      memory_ratings[name].append((res, rating))

  compressed_memories = {}
  for name in town_people.keys():
    memories_sorted = sorted(
          memory_ratings[name], 
          key=lambda x: x[1]
      )[::-1]
    relevant_memories = memories_sorted[:MEMORY_LIMIT]
    memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
    res = generate(prompt_meta.format(prompt))
    compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
    compressed_memories_all[name].append(compressed_memories[name])

  place_ratings = {}

  for name in town_people.keys():
    place_ratings[name] = []
    for area in town_areas.keys():
      prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      place_ratings[name].append((area, rating, res))
    place_ratings_sorted = sorted(
        place_ratings[name], 
        key=lambda x: x[1] )[::-1]
    if place_ratings_sorted[0][0] != locations[name]:
      new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
      compressed_memories_all[name].append(new_recollection)
    locations[name] = place_ratings_sorted[0][0]
# Out:
# Toblen Stonehill Edermath Orchard 9 At 9:00, I explored nearby towns to meet new people and complete my research on new products.
# Daran Edermath Tresendar Manor 9 I woke early to make sure I completed my morning tasks of writing and reading the morning paper. I made breakfast and started setting up some preparations. I took a leisurely walk in order to explore and clear my mind. After that, I took a break and rested.
# Linene Graywind Edermath Orchard 9 Linene planned to explore the village.
# Halia Thornton The Sleeping Giant 9 I met up with Halia Thornton at the Sleeping Giant to chat about the challenges and opportunities ahead.
# Qelline Alderleaf Lionshield Coster 9 Kellen was going through the town. She had met with the locals and discussed the situation. She made a simple breakfast and then had moments for reflection. She also had hope to find Robbing Nellie.
# Sister Garaele Alderleaf Farm 9 I read some books and researched Tymora, talked to Qelline, and organized the tasks for the next week.
# Harbin Wester Townmaster’s Hall 9 I set up for an orc battle. I talked to Harbin Wester. I found Conrad Scarface. I shot into the enemys guarded room.
# Terrill Five Fingers Lionshield Coster 9 I prepared for the raid. I also prepared for the hunt. I held a town hall meeting at 10:30 and then hunted and captured Quillin by 12:30.
# Conrad Scarface Townmaster’s Hall 9 I set off to the nearby village to take down the orcs who have attacked the town. I looked around the settlement for anything interesting.
# Robbing Nellie Lionshield Coster 9 I hide the map, collect money, get the map for Nellie.
# Valerie the Grin Shrine of Luck 9 I wandered in the shrine and made some observations.
# Toblen Stonehill Edermath Orchard 10 I explored nearby towns to meet new people and gain insight into the areas culture.
# Daran Edermath Edermath Orchard 10 I worked on my puzzle or activity for an hour. I then went for a leisurely walk for 15 minutes and then relaxed for 15 minutes until it was time for me to enter bed for an early night.
# Linene Graywind Shrine of Luck 10 Linene talked to Sister Garaele.
# Halia Thornton Townmaster’s Hall 10 In the next hour, I prepared my presentation to the local Chamber of Craftsmen.
# Qelline Alderleaf Phandalin Town Square 10 I got ready for dinner. I made plans for the next day.
# Sister Garaele Shrine of Luck 10 Sister Garaele practiced her magic skills, found something to do with the Harpers and got to know Linene Graywind before continuing on with her day.
# Harbin Wester Townmaster’s Hall 10 I prepared the town hall for the meeting. I met with Halia Thornton and Harbin Wester. I fought Conrad Scarface. I finished.
# Terrill Five Fingers The Sleeping Giant 10 I started preparation for the raid. I prepared for the hunt. I captured Quillin.
# Conrad Scarface Townmaster’s Hall 10 I recollected for 1 hour from 10.00 to 11:00.00.
# Robbing Nellie Tresendar Manor 10 In the next hour, I investigated the nearby rooms and explored the area of Tresendar Manor. I tried and identified the map lead if possible. Afterwards, I tried and obtained the map and the associated items from Robbing Nellie.
# Valerie the Grin Barthen's Provisions 10 Valerie the Grin stayed in Barthens Provisions until noon. She robbed or killed any adventurers who dare to challenge her in a more stealthy and organized manner, ensuring no one else was unprepared. She left her cloak and map of the Redbrand ruffians on the table and chatted for an hour until noon. When noon arrived, she found a way to kill any more adventurers who dare to challenge her.
# Toblen Stonehill Edermath Orchard 11 I spent the next hour exploring the nearby towns and making new friends.
# Daran Edermath Edermath Orchard 11 I had gone out for a leisurely walk, exploring the town. I met the other characters and asked them about their jobs, businesses, and any news that had broken in the news. I then took a nap of rest, and at 11:20 I had lunch. I then left around 12:30 and went to bed for an early night, finally setting out for a night of adventures in the nearby forest.
# Linene Graywind Lionshield Coster 11 I explored the village. I finished work by 7:30 pm. I read or slept before tomorrows long journey.
# Halia Thornton Edermath Orchard 11 I met Halia Thornton. When I was at the office, I encountered Halia, and we talked about the future. I asked her questions about her hobbies and what she wanted to do for work. I was impressed with her intelligence and curiosity. We had a great dinner together and I knew I wanted to be working with Halia again.
# Qelline Alderleaf Edermath Orchard 11 I made dinner and then moved to Phandalin Town Square to meet up with Toblen Stonehill and the others.
# Sister Garaele Lionshield Coster 11 In the next hour, I spent some time trying to figure out what happened to the Lionshield caravan and helping the Harpers.
# Harbin Wester Tresendar Manor 11 I prepared the town hall for the upcoming meeting.
# Terrill Five Fingers Edermath Orchard 11 Terrill Five Fingers plan in the next hour was to meet up with Toblen Stonehill, Halia Thornton and take some time to prepare for the attack.
# Conrad Scarface Phandalin Town Square 11 Conrad explored the city and found something interesting.
# Robbing Nellie Phandalin Town Square 11 I stalked Nellies location, collected a map, and stole money.
# Valerie the Grin The Sleeping Giant 11 I joined Val and Barthen in celebrating the midnight sunset.
# Toblen Stonehill Edermath Orchard 12 I met Terrill Five Fingers. we talked about the day, made a trade, and then headed to the redbrand gallows.
# Daran Edermath Shrine of Luck 12 I took a quick nap in order to recharge and then continued exploring the shrine.
# Linene Graywind Lionshield Coster 12 I set up the trading tables, tallied the money and started looking for new customers. I was ready to go at 1:00 pm.
# Halia Thornton Stonehill Inn 12 Halia Thornton enjoyed a drink and looked forward to meeting people.
# Qelline Alderleaf Shrine of Luck 12 Quillen made dinner and then visited Daran Edermath. Sister Garaele joined her.
# Sister Garaele Shrine of Luck 12 I prepared for the Town Hall Meeting. I spent time with Daran Edermath and Qelline Alderleaf. I attended a gathering with Harpers. I preparing for the next weeks tasks.
# Harbin Wester Tresendar Manor 12 I prepared the town hall for the meeting.
# Terrill Five Fingers Edermath Orchard 12 I began the attack at 12:30.**
# Conrad Scarface Tresendar Manor 12 I set out in the next hour and explored the ruins and nearby village. I kill any Redbrands that I come across and then set out on my mission. I also visited an abandoned farm to see if I could help with it. I also did whatever it took to find the lost Redbrand camp and eventually escape.
# Robbing Nellie Edermath Orchard 12 I should try to locate and steal a map from Toblen Stonehill and take it while avoiding Terrill Five Fingers .
# Valerie the Grin Phandalin Miner's Exchange 12 I took Val out for lunch so she could rest and refuel.
# Toblen Stonehill Shrine of Luck 13 I talked to Qelline and Valerie.
# Daran Edermath Townmaster’s Hall 13 Daran investigated the orc presence near Wyvern Tor as part of his daily self-care routine.
# Linene Graywind Townmaster’s Hall 13 I visited the orcs and hunted for treasure.
# Halia Thornton Phandalin Town Square 13 I prepared my presentation and visited the mining company in the next hour.
# Qelline Alderleaf Shrine of Luck 13 Queenlaine walked to Toblen Stonehill and exchanged goods with him, setting her up a deal. After that, she had a leisurely lunch with Valerie the Grin, before setting off again to continue her journey.
# Sister Garaele Phandalin Town Square 13 I set aside time to read and research. I practiced my magic. I talked to Halia Thornton and Harbin Wester. I had a chance to discuss the town halls preparation for the meeting. I tried to find something to do with the Harpers. I ate breakfast and made a list of tasks for the next week. I contemplated the days events.
# Harbin Wester Phandalin Town Square 13 I prepared the town hall for the meeting and gave the opening speech. After that, I spoke to Sister Garaele and Halia Thornton to find out their thoughts on the meeting.
# Terrill Five Fingers Townmaster’s Hall 13 I started my preparations for the raid.
# Conrad Scarface Lionshield Coster 13 I sneaked into the nearby village and attempted to capture a valuable cargo shipment in a high-risk area for a quick profit.
# Robbing Nellie Phandalin Miner's Exchange 13 I have an encounter with Robbing Nellie, who tries to rob me.
# Valerie the Grin Shrine of Luck 13 I stopped for a coffee and a bite to eat and watched the sunrise on the horizon.
