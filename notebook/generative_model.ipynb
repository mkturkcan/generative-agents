# %% [markdown]
# ## Installation
#
# We will need to install a number of libraries to start with.

# %%
import networkx as nx
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 74.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.27.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.98

# %% [markdown]
# We use flan alpaca model for speed and local execution.

# %%
from transformers import pipeline

prompt = "Write an email about an alpaca that likes flan"
model = pipeline(model="declare-lab/flan-alpaca-xl", device=0)
model(prompt, max_length=128, do_sample=True)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# [{'generated_text': "Dear Alpaca (name changed), I wanted to share a secret with you. I have been taking care of my alpaca since its birth and I know that she can make an amazing breakfast from flan. She loves to eat it every day after her meals and is often seen munching on the leftovers. She would be completely oblivious to the fact that the food was made from an alpaca's body and is very much a 'flavorizer'. I'm really excited to hear that she can eat flan in her 'flavorizer"}]

# %%
from transformers import pipeline
import networkx as nx
prompt = '''### Instruction:
Who is the first person on the moon?

### Response:'''
def generate(prompt):
  output = model(prompt, do_sample=True, min_length=10, max_length=len(prompt)+128)
  out = output[0]['generated_text']
  if '### Response:' in out:
    out = out.split('### Response:')[1]
  if '### Instruction:' in out:
    out = out.split('### Instruction:')[0]
  return out

# %% [markdown]
# ## World Description
# We describe the world below. We will generate prompts based on this information. The simulation is that of the town of Phandalin, southwest of Neverwinter. This area is chosen because it is easily extendable with multiple regions for a "player" to be able to explore the world once the simulation is done.

# %%
world_graph = nx.Graph()

prompt_meta = '''### Instruction:
{}

### Response:'''

town_areas = ["Barthen's Provisions", "Lionshield Coster", "Stonehill Inn", "Phandalin Town Square"]
town_areas = {"Phandalin Town Square": 'Town square of the town of Phandalin.',
              'Stonehill Inn': "In the center of town stands a large, newly built roadhouse of fieldstone and rough-hewn timbers. The common room is filled with locals nursing mugs of ale or cider, all of them eyeing you with curiosity.",
              "Barthen's Provisions": "Barthen’s is the biggest trading post in Phandalin. Its shelves stock most ordinary goods and supplies, including backpacks, bedrolls, rope, and rations. The place is open from sunup to sundown.",
              "Edermath Orchard": "A tidy little cottage beside an apple orchard.",
              "Lionshield Coster": "Hanging above the front door of this modest trading post is a sign shaped like a wooden shield with a blue lion painted on it. This building is owned by the Lionshields, a merchant company based in the city of Yartar, over a hundred miles to the east. They ship finished goods to Phandalin and other small settlements throughout the region, but this outpost has been hard hit by banditry. The most recent Lionshield caravan due in Phandalin never arrived.",
              "Phandalin Miner's Exchange": "The Miner’s Exchange is a trading post where local miners have their valuable finds weighed, measured, and paid out. In the absence of any local lord or authority, the exchange also serves as an unofficial records office, registering claims to various streams and excavations around the area. There isn’t any real gold rush in Phandalin, but enough wealth is hidden in the nearby streams and valleys to support a good number of independent prospectors. The exchange is a great place to meet people who spend a lot of time out and about in the countryside surrounding Phandalin. The guildmaster is an ambitious and calculating human woman named Halia Thornton.",
              "Alderleaf Farm": "A farm owned by the helpful halfling farmer, Qelline Alderleaf.",
              "Shrine of Luck": "Phandalin's only temple is a small shrine made of stones taken from the nearby ruins. It is dedicated to Tymora, goddess of luck and good fortune.",
              "The Sleeping Giant": "This rundown tap house is a dirty, dangerous watering hole at the end of Phandalin’s main street. It is frequented by Redbrand thugs and operated by a surly female dwarf named Grista.",
              "Townmaster’s Hall": "The townmaster’s hall has sturdy stone walls, a pitched wooden roof, and a bell tower at the back. Posted on a board next to the front door is a notice written in Common. It reads: “REWARD — Orcs near Wyvern Tor! Those of a mind to face the orc menace should inquire within.” The notice bears the town’s seal and an indecipherable signature.",
              "Tresendar Manor": "A ruined manor. The Redbrands’ base in Phandalin is a dungeon complex under Tresendar Manor. Before the manor was ruined, its cellars served as safe storage for food and water in the event that the estate was attacked, while an adjoining crypt provided a resting place for the deceased members of the Tresendar family. The Redbrands have since expanded the cellars to suit their own purposes, adding slave pens, workshops, and barracks."
              }
town_people = {"Toblen Stonehill": "Owns a trading post.", 
               "Daran Edermath": "Daran Edermath is a retired adventurer who lives in a tidy little cottage beside an apple orchard. A fit, silver-haired half-elf well over a hundred years old, Daran is a fighter who served as a marshal and herald for many years in the lands of the Dragon Coast, far to the southeast. Upon retiring, he returned to the Neverwinter region, his original home.",  
               "Linene Graywind": "Runs a trading post.",  
               "Halia Thornton": "An ambitious and calculating human woman. She is the guildmaster of Phandalin Miner’s Exchange, a trading post where local miners have their valuable finds weighed, measured, and paid out. In her attempts to establish the Miner's Exchange as the closest thing the town has to a governing authority, she acts as more than a simple merchant.",  
               "Qelline Alderleaf": "A wise female halfling of forty-five, Qelline Alderleaf is a pragmatic farmer who seems to know everything that goes on in town. She is a kind host, and is willing to let the characters stay in her hayloft if they don't want to stay at the Stonehill Inn.",  
               "Sister Garaele": "Elf cleric of Tymora and Harper agent.", 
               "Harbin Wester": "Townmaster of Phandalin. A pompous, old food. Phandalin has no functioning government, but the townsfolk elect someone to serve as townmaster each year. The townmaster serves as a judge in minor disputes and keeps any records that need to be kept.",
               "Terrill Five Fingers": "A human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Conrad Scarface": "A human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Robbing Nellie": "A human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               "Valerie the Grin": "A human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               }
for town_area in town_areas.keys():
  world_graph.add_node(town_area)
  world_graph.add_edge(town_area, town_area)
for town_area in town_areas.keys():
  world_graph.add_edge(town_area, "Phandalin Town Square")
locations = {}
for i in town_people.keys():
  locations[i] = "Phandalin Town Square"


memories = {}
for i in town_people.keys():
  memories[i] = []
plans = {}
for i in town_people.keys():
  plans[i] = []

global_time = 8
def generate_description_of_area(x):
  text = "It is "+str(global_time)+":00. The location is "+x+"."
  people = []
  for i in locations.keys():
    if locations[i] == x:
      people.append(i)

# %%
compressed_memories_all = {}
for name in town_people.keys():
  compressed_memories_all[name] = []

# %%
for name in town_people.keys():
  prompt = "You are {}. The following is your description: {} You just woke up. What is your goal for today? Write it down in an hourly basis, starting at {}:00. Write only one or two very short sentences. Be very brief. Use at most 50 words.".format(name, town_people[name], str(global_time))
  plans[name] = generate(prompt_meta.format(prompt))
  print(name, plans[name])
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Toblen Stonehill Tomorrow – Toblen will focus on building trust with customers and employees by providing prompt, reliable services. 8:00am: Wake up and stretch, then make breakfast. 9am: Spend time reading and completing tasks. 10:00am: Talk to someone about your goals for the day. 11:00am: Make sure your customers get what they need by checking the shelves in the market and answering their questions.
# Daran Edermath Morning. 8.5. Spend some time planting a new apple tree near my cottage. 9. 8.5. Have lunch with friends and read a book online. 10. 1.5. Read through a newspaper article. 11. 8.5. Prepare for a meeting at 11 am. 12. 8.5. Spend some time with friends and read a book online. 13. 8.5. Prepare for a meeting at 12 pm. 14. 8.5. Have lunch with friends and read a novel in the evening. 15. 8.5. Have a chat with friends in an online chat. 16. 8.5. Have dinner with friends and watch an online video together. 17. 8.5. Meditate. 17. 8.5. Have a virtual chat to get caught up with some friends. 18. 9. 8.5. Have a night out with friends and go to sleep early
# Linene Graywind This morning I plan to get ready for work at 8:00 and start the day off with some serious work. I also plan to have lunch at approximately 1:00 and set a goal for myself for the rest of the day.
# Halia Thornton Aim for: - To maintain a profit of at least 2200 gp on the trading post. - To find new sources of supplies. - To improve my communication and negotiation skills. - To create a plan on how to approach a new customer. - To explore opportunities in the town. - To build trust with new vendors.
# Qelline Alderleaf Aim: Start working on the vegetable garden I am currently tending. Time: 1pm Start on cleaning and organizing my house. Aim: 10am Start cooking lunch, with the intention of finishing it by lunch time. Time: 12pm Begin the day with breakfast, taking the time to ensure all of my dishes are ready. Aim: 3pm Have lunch, have a drink and a chat with my friends before heading out into the forest. Task: Then, talk about what I accomplished and what I want to do tomorrow. Task: Start the day with a cup of tea and a chat with my friends. If necessary, continue with some work and research. Task: 1:00pm Start studying for the
# Sister Garaele My goal for today is to spend some time connecting with the people of Tymora. I might spend some time reading and discussing with the locals or going for a leisure walk. I could also get some rest. I should also check on any current events and make sure I am up-to-date with the happenings in Tymora. Afternoon: Become familiar with the city and its potential opportunities. Afternoon: Gather data and insights regarding different areas of the realm. I could also research the culture for the chance to travel out of my home. Night: Get ready and head to bed early so I can have the best of the day tomorrow.
# Harbin Wester Today I want to: - Reach out to some citizens with the message of hopeless situation - Take part in a community meeting - Establish meaningful relationships between citizens - Read a book or watch a movie - Spend some time doing something relaxing Today I want to: 1. Make sure everyone in town is on the same page 2. Make sure everyone has the same goals and objectives 3. Spend some time outside, like taking a walk 4. Make sure everyone is on the same page and doing what is right Today I will: 1. Try to make contact with some citizens that may have a problem today 2. Go for a long morning walk and a conversation with my friend 3. Meet with the CEO of town to discuss the latest issues 4. Ask
# Terrill Five Fingers Today I plan to: - Go out to meet with the other Redbrand ruffians. - Rip off an adventurer on the way to an island. - Capture a guard at a nearby tavern. - Make plans to visit the town of Crich at 1pm. - Talk to a thief in the town at 1pm. - Have lunch with a rogue merchant. - Find a safe place for the day. - Set up an ambush on a nearby village at 3pm.
# Conrad Scarface Conrad Scarface 8:10 AM He is up early to rumble until the sun rises and he can do other things. 8:20 AM He has breakfast, then heads to town. 8:25 AM On patrol, he catches a bad guy and gets away. 9:00 AM He meets with a new person and talks about his plans for a criminal empire. 11:30 AM He is back in town and visits another bar. 12:00 PM He is waiting for the sun to come out, then back off to bed quickly.
# Robbing Nellie This morning I'm going to work on my goal to visit a few nearby towns and gain further information on the people I am attempting to kill. This evening I plan to go to a nearby restaurant and enjoy a delicious dinner. Tomorrow I plan to attend a business meeting and hear about potential investments. I then plan to spend the evening relaxing with friends.
# Valerie the Grin morning: I plan to rob a few people in the village. I will have lunch later. evening: I set out to find a good place to kill an adventurer. I will be ready to take him by surprise in any way.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)
  
  for name in people:
    prompt = "You are {}. Your plans are: {}. You are currently in {} with the following description: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, town_areas[location], str(global_time), ', '.join(people))
    people_description = []
    for i in people:
      people_description.append(i+': '+town_people[i])
    prompt += ' You know the following about people: ' + '. '.join(people_description)
    memory_text = '. '.join(memories[name][-10:])
    prompt += "What do you do in the next hour? Use at most 10 words to explain."
    action_prompts[name] = prompt

# %%
action_results = {}
for name in town_people.keys():
  action_results[name] = generate(prompt_meta.format(action_prompts[name]))
  # Now clean the action
  prompt = """
  Convert the following paragraph to first person past tense:
  "{}"
  """.format(action_results[name])
  action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
  print(name, action_results[name])
# Out:
# Toblen Stonehill I woke up and stretched, then made breakfast. I spent time reading and completing tasks. I talked to someone about my goals for the day.
# Daran Edermath Daran talked to everyone in town one by one. He also read the newspapers for any new developments in the area. Then he had lunch with his friends and watched an online movie with Halia and others.
# Linene Graywind Linnet set lunch at 11:30. (The sentence is now in the past tense.)
# Halia Thornton I made introductions, found new sources of supplies, improved communication and negotiation skills, created a strategy for approaching a new customer, explored opportunities in the town, and built trust with new vendors.
# Qelline Alderleaf I had greeted my friends, and joined the small gathering that was playing in the square. I talked to Toblen Stonehill and Harbin Wester, and then looked around the square. I interacted with the other ruffians, caught up with Qelline Alderleaf and Halia Thornton, and took a seat at the nearby bar.
# Sister Garaele Gather information on local culture. Set up meetings with Toblen, Daran, and other Phandalinites.
# Harbin Wester I had been assigned to join the Phandalin Town Square party at 8 PM. I was taking part in various conversations regarding town events, as well as leading an investigation into this particular incident. I was using the knowledge gained from the game to gain an insight into what happened, and was working towards resolving this issue as quickly as possible.
# Terrill Five Fingers I went out to meet Redbrand ruffians. I captured a guard at a nearby tavern. I talked to a thief in town at 1 pm. I had lunch with a rogue merchant. I set up an ambush on a nearby village at 3 pm.
# Conrad Scarface I spent the morning rumbling and drinking in the Town Square, then lunch with Halia and the other ruffians. In the afternoon, I spent time setting my targets for the night, either ambushing them or stealing their stuff. I take the rest of the evening to plan my crimes, ensuring that Im always ready for the morning twilight.
# Robbing Nellie I picked up items from Toblen Stonehills trading post. I also look around while Robbing Nellie speaks to Toblen Stonehill and Sister Garaele. I worked on my goal to visit a few nearby towns and gain further information on the people I am attempting to kill. I will also enjoy a delicious dinner with friends. Finally, I attended a business meeting to learn about investments and then spent the evening making friends.
# Valerie the Grin I robbed a few people in the village, then had lunch later. I then set out to find a good place to kill an adventurer.

# %% [markdown]
# Collect the memories people observe.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)
  
  for name in people:
    for name_two in people:
      memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

# %% [markdown]
# # Rank Memories

# %%
import re
def get_rating(x):
  nums = [int(i) for i in re.findall(r'\d+', x)]
  if len(nums)>0:
    return min(nums)
  else:
    return None

# %%
memory_ratings = {}
for name in town_people.keys():
  memory_ratings[name] = []
  for i, memory in enumerate(memories[name]):
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], locations[name], str(global_time), memory)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    memory_ratings[name].append((res, rating))
  print(memory_ratings[name])
# Out:
# [('5 (important) I care about this greatly.', 5), ('5 (I care about this greatly). You take initiative and do things to help people, and this shows your dedication to caring.', 5), ('I care about this. [["Linnet set lunch at 11:30" now has a rating of 3].', 3), ("2.5. I am still undecided on how I want to engage in tomorrow's task. I may make a call to discuss.", 2), ('5 star. I care deeply about this, and I am dedicated to making sure it appears exactly as I dreamed.', 5), ('I care about this task, but it may be inefficient given how quickly it needs to be completed and how important it is to the success of my overall plans.', 0), ('4 rating. I care a great deal about the integrity of the game and believe it is essential we have a solid game system in place to ensure that everything we do is of the highest quality. This will help ensure we can continue to compete with the best companies in the world.', 4), ("3/10. Toblen is interested in Terrill's activities, but there might be things he should be doing – such as finishing his tasks around 8:00, making sure his tasks are finished promptly, and providing other tasks – which he could spend that time on instead.", 0), ('1 out of 5. I do not care very much about this.', 1), ('4/5. As a seasoned trader and worker in the town square, I can appreciate the work of Robbing Nellie.', 4), ('2 because it is not something I care about.', 2)]
# [('I care about this very much. I had a great day yesterday, and it has given me an amazing feeling of purpose and accomplishment!', 0), ("4 (Excellent) We can appreciate Daran's effort.", 4), ("I care about this. I have been here until I reach my destination and I need to be finished by 11 am. I cannot be in Phandalin Town Square at 8 am since this won't be possible. I need to be out and about in the Square before lunch so I find a time that works for me.", 8), ('4/5. This activity is important for furthering my development and understanding of the town.', 4), ('4/5. The memories stored in the memory provide a vivid physical representation of the atmosphere and interactions in the square.', 4), ('I care about this a lot. I want to make sure the local community has access to quality resources and can benefit from its culture. In addition, I want to ensure that all members of the Phandalinite community have the opportunity to participate in dialogue that promotes understanding and respect among everyone.', 0), ('4/5. I care greatly for this situation and am working hard to investigate and respond to it swiftly.', 4), ('4/5. These actions and memories are highly meaningful to me and I am invested in them. I have outlined a plan to complete them and make this day meaningful for myself and the people surrounding me. If anything, my actions and memories help to remind me of the importance of staying dedicated to my goals and helping to make this world a better place. I am eager to see where the adventures of Terrill Five Fingers take me.', 4), ('4.00. I care about this. It is a meaningful reflection on the way Conrad Scarface spends his time.', 0), ('3/5 in how much I care about this.', 3), ('4/10. The memory of Valerie the Grin is something that I can appreciate. It reflects the true, dark nature of the game, and provides an escape from the everyday. In this memory, she reflects back on her past actions and their consequences. She is a villain, but she has a moral center - she is trying to make sure that her legacy is untouched by the darkness. Despite this, I care deeply about her and her legacy.', 4)]
# [('4/5. This morning was a success.', 4), ("1/10. It is inconvenient for me to be present in the Square with Daran now, so it is not a priority. What I'm working on now needs to be better organized and priority-based.", 1), ("3 (I don't care) since I already set my lunch at 11:30.", 3), ("4/5. I am very interested in Halia's story and learn a lot from her experiences. I look forward to her future adventures.", 4), ("2/5. I care about this event very much and am delighted to have it in my memory. It reminds me of memories that I have made when I was younger and of what was important in life. I am also very glad that I could be there with my friends who hadn't changed so much over the years. It was a fun morning and I am proud of my record for how much I have gone through since then.", 2), ("I care about this a lot. I believe it's important to learn more about the local culture and create meaningful connections with people.", 0), ("3 (Interesting) [By the time I get ready for work, I will have finished my day's work. I'll start my work with a goal.]", 3), ('4/5, I care about this a lot.', 4), ('3 (Interesting). You admire Conrad Scarface for his ability to adapt to different social situations and make the most of his leisure time.', 3), ("The rating is 3. Toblen Stonehill knows about Linene's plans and can help with resolving the issue.", 3), ('1 (Not relevant to my actions) The memory of Valerie the Grin is irrelevant to my actions.', 1)]
# [('3/5. I care about the memory of Toblen Stonehill, as it helps me understand his routine and build trust with the other vendors.', 3), ("3/5. This action is highly commendable, showing great effort and dedication on Daran's part. Even though I have a few goals for the trading post I'm currently working on, I'm also excited to learn more about the community and have a positive impression of Daran's work.", 3), ('Rating: 3/5. This is an important reminder to make sure lunch is set on time.', 3), ('4/5. I am genuinely invested in making sure I achieve my goals and am committed to doing my part in making the trading post a success.', 4), ("3/5. This is a great opportunity for me to explore the town and make some connections. I can also make use of the information from Qelline's memory to make a plan of how to approach the new customer. I will work to build trust with new vendors and reach my goals.", 3), ('3/5. It is obvious that Sister Garaele has a lot of work to do to improve the cultural understanding of Phandalin and to set up meetings with Toblen, Daran, and other Phandalinites, but she is also willing to spend some of her time helping you out as well. She could definitely help with some of your more difficult problems like understanding the various language and culture issues on offer in Phandalin.', 3), ('5 I care about this very much and I am glad to see that Harbin Wester is doing their part to help resolve this issue.', 5), ('5 (Careful) - I care deeply about what Terrill 5 Fingers does in town and I want to learn more about how to be a better rogue.', 5), ("3/5. This is information that is important and valuable to Halia's success. It will allow her to better understand the motivations and actions of her rival, Conrad Scarface, and how she can gain a competitive edge. It will also help her to understand the town better and take advantage of its opportunities. Lastly, it will help her to build trust with new vendors and strengthen her network of resources. Achieving these goals is an essential part of Halia's success.", 3), ('3 (Interesting), but I would like to focus on how I can contribute towards achieving my goals.', 3), ('I care about this at 3/5 because it will inform my decisions later. It is more than likely that I will need to find ways to make better contacts with vendors in the town and I will need to use these contacts to my advantage when exploring potential opportunities.', 3)]
# [("4/5. You care greatly about Toblen's accomplishments and are proud to have him as a friend.", 4), ('3/5. It is a wonderful way to spend the morning.', 3), ("3 out of 5 stars. I care about the fact that Linnet arranged lunch for 11:30, so if you ever need my help, don't hesitate to ask!", 3), ('4/5. I care about this immensely.', 4), ('Yes, I care about this. Aim: 4 pm Start organizing my house', 4), ("2/5. I find the task interesting but it can be time consuming. I would like to find more time to dedicate to this as I'm looking to get going in the morning.", 2), ('4 (Very Highly) It is my duty as a player to make sure the players of the game are as safe as possible. I care dearly about the safety of my players, so I am taking this matter seriously.', 4), ('4 (important) - You may care about it if it is relevant to your mission.', 4), ('3 (Not very focused) "Your time is running late, so quickly return to your seat and linger a while while the others have already left for the day. Once i return, it will be time to start your work, your work is done." "Your time is running late, so quickly return to your seat and lie down. Once i return, it will be time to leave for the day." "Your time is running late, but slowly but steadily you find yourself slipping away into the shadows around you."', 3), ("3/5. This gives you enough time to accomplish your goals and make all the necessary progress until you can head back to the settlement. Observing the other players' movements can allow you to gauge the attitudes of each character and their motivations. Although you may not be planning your day with full intention, the activity can help you understand each team's goals and help gauge how close you are to achieving them.", 3), ('4 (Really interested) The time is 8, and I observe Valerie the Grin with an interest. Even though her memory of the previous day is incongruous with my own, her act of robbery and murder at 8am are enough for me to care about it enough to leave.', 4)]
# [('3 (It is not important, but should be done to ensure progress).', 3), ('3 (a bit much) but I can understand why it is important to you and your goals for the day.', 3), ('3/5 I care about this. It will help me stay connected to the people of Tymora.', 3), ('5 Because this is important to me, and it gives me the opportunity to invest in my community.', 5), ('3/5. My time in Tymora has been extremely valuable and I am so thankful for the opportunity. I am making great progress on my goals and am so proud of my accomplishment.', 3), ('3/5. The local culture is an extremely important part of my life and I am eager to learn more about it.', 3), ('5 I care about this a lot.', 5), ('2/5. The activities of Terrill Five Fingers seem to be occupying too much of my time and I am not as keen on understanding their background.', 2), ("2 (I am very interested in how this affects Sister Garaele's plans).", 2), ('5 (important) I am eager to observe this scene as it provides valuable insight into the life of an individual in Tymora.', 5), ('3/5. I am not really interested in this.', 3)]
# [('You care about this highly. You would rate it as high as 3 out of 5.', 3), ("5 I care about this greatly. It's inspiring to see a person who has such a positive attitude, engaging and providing meaningful things to the citizens.", 5), ("3/5. Linnet Graywind's memory of setting lunch at 11:30 is an important piece of information to recall.", 3), ('3/5. This is an interesting memory that I care about greatly.', 3), ('5 (Personally) I care about this very much.', 5), ('3 I care about this. Please help me complete this task today.', 3), ('4 (I care deeply). I see that it would be beneficial to reach out to people that may need help today. I aim to talk to as many people as possible today to hear their stories and how they are working to make the situation better.', 4), ('3/5. Although this situation could potentially be dangerous, the character displayed in it has the characteristics of a strong, self-reliant protagonist and gives a clear understanding of what the world wants to see.', 3), ("2 out of 5 stars. The description of Conrad Scarface's day is very vivid and interesting.", 2), ('5 (I care about this) and make sure to spread the news to the players.', 5), ("2 out of 5. I appreciate it's not as silly as it might seem.", 2)]
# [('2/5. I take note of the meticulous preparation you have put into this trip and admire how it speaks to the importance of effort and achieving goals. I will be sure to put my resources into improving the situation if possible.', 2), ('I care about this quite a bit.', 0), ('3 (Rapidly important)!', 3), ('3/5. You have a goal of killing every member of the Redbrand gang. Therefore, you care deeply about any success you may have achieved.', 3), ('4! This is so much fun! I thoroughly enjoyed every minute of it.', 4), ("2 (Minor) concern. I only have time for 10 minutes before Sister Garaele's meeting starts, so I cannot help but be impressed by her dedication to the task.", 2), ("I care about this a lot. I'm observing Harbin's efforts to resolve an issue in the town, and I think it's admirable to see him actively using his knowledge in the game to find out what happened and how to make it better. I also admire his drive to solve the matter and his willingness to let the community know about how they are making progress. I'm impressed with his dedication and ambition.", 0), ('4 out of 5 stars. This entry deserves a special rating, as it deserves to be remembered.', 4), ('5 (I care about this a lot)', 5), ("I care about this memory a lot. I find it very motivating to take on the challenge of exploring the world and meeting new people. I also think Robbing Nellie's actions are exemplary, and I admire his ambition and ambition of achieving his goals. I am very impressed with his dedication and dedication to achieving his goals.", 0), ('4/5. This scenario has taught me a valuable lesson: it is better to think twice before taking action even if you think you have nothing else to lose.', 4)]
# [('3/5 (Not too important) but it could be improved.', 3), ('3/5. You care about this because it adds to your social standing as a person.', 3), ("3 (Not important) This observation is not relevant to Conrad Scarface's day, as he has no intention of engaging in the activity.", 3), ('5 I care a lot about the memory of Halia Thornton.', 5), ('5 (highly attentive) **** I care about this a lot.', 5), ('3/5. I care about this because it will help me grow my criminal empire.', 3), ('4 (care) in regards to the incident with Harbin Wester.', 4), ('3/5. This is a significant amount of time that Conrad Scarface spends doing the actual work.', 3), ('3 Out of 5. This game is probably for people who are more interested in the visuals, so I am rating it 3 out of 5.', 3), ('3 (partly interested, partially uninterested)', 3), ("3/5. I care very little about this, since I'm only doing this to get ahead.", 3)]
# [('3/5. Toblen is really cool and I respect how he spends his morning time. I would like to learn from him so I can better plan out my day. I am sure he can help me with my goals.', 3), ('5 because it does not interfere with my goals.', 5), ('3 (Care) This is very important for me, as it will help me gain more information on Nellie, and help me get the items I need. Thank you for taking the time to read this.', 3), ('5 (very much) ', 5), ('4/5. I care a lot about my experience in Phandalin Town Square this morning.', 4), ('3 I care about this quite a bit.', 3), ('4/5. You care greatly about the issue and are working hard to investigate. I can see you having a positive impact on the town.', 4), ('2/5. You care about this memory and want to try and replicate it. You want to be an effective and successful thief and be confident you are able to pull off the mission.', 2), ("3/10. The description of Conrad's day is very interesting; he appears to be very successful at his crimes!", 3), ('Rating: 4/5. Your planning looks very focused and ambitious, and you have put thought into every detail.', 4), ("3/5. You care about this moment very much, as it is the only time you'll have to make an actual effort to do something besides killing someone.", 3)]
# [('3/5 because it is nice to hear someone care about the environment. I care about other people, including myself, and I try to be thoughtful and considerate, and I care about my actions.', 3), ('3/5. That means you care a lot about other people, and are likely feeling envy and regret.', 3), ('3 (Not very important) This information matters to me because it indicates what time I should be ready to kill an adventurer, so I do care about it.', 3), ('4 (Best) This is something I care about a lot.', 4), ('3/5. The events in Phandalin Town Square mean a lot to Valerie, because they demonstrate how much she cares about others.', 3), ('2/5 stars. I care about the local culture and the people of Phandalin but I am unable to take the time to learn it as I have other plans.', 2), ('3 (Careful) or 4 (Probing)', 3), ("3/5. It is incredibly important for Valerie to have Terrill Five Fingers' plans. He is the key figure in making sure that these plans are carried out.", 3), ('3 (Not caring). I am getting bored and should have more exciting adventures.', 3), ("4/5. I care a great deal about the other characters' reactions and interactions with us, and make sure that these stories are included as part of my ongoing story.", 4), ("4 (Careful) [The memory of Valerie the Grin's actions is very important.]", 4)]

# %% [markdown]
# # Compress Memories

# %%
MEMORY_LIMIT = 10
compressed_memories = {}
for name in town_people.keys():
  memories_sorted = sorted(
        memory_ratings[name], 
        key=lambda x: x[1]
    )[::-1]
  relevant_memories = memories_sorted[:MEMORY_LIMIT]
  # print(name, relevant_memories)
  memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
  prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
  res = generate(prompt_meta.format(prompt))
  compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
  compressed_memories_all[name].append(compressed_memories[name])

# %%
place_ratings = {}

for name in town_people.keys():
  place_ratings[name] = []
  for area in town_areas.keys():
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    place_ratings[name].append((area, rating, res))
  place_ratings_sorted = sorted(
      place_ratings[name], 
      key=lambda x: x[1]
  )[::-1]
  if place_ratings_sorted[0][0] != locations[name]:
    new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
    compressed_memories_all[name].append(new_recollection)
  locations[name] = place_ratings_sorted[0][0]

# %% [markdown]
# # Put it all together

# %%
for repeats in range(5):
  global_time += 1
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)
    
    for name in people:
      prompt = "You are {}. Your plans are: {}. You are currently in {} with the following description: {}. Your memories are: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, town_areas[location], '\n'.join(compressed_memories_all[name][-5:]), str(global_time), ', '.join(people))
      people_description = []
      for i in people:
        people_description.append(i+': '+town_people[i])
      prompt += ' You know the following about people: ' + '. '.join(people_description)
      memory_text = '. '.join(memories[name][-10:])
      prompt += "What do you do in the next hour? Use at most 10 words to explain."
      action_prompts[name] = prompt
  action_results = {}
  for name in town_people.keys():
    action_results[name] = generate(prompt_meta.format(action_prompts[name]))
    # Now clean the action
    prompt = """
    Convert the following paragraph to first person past tense:
    "{}"
    """.format(action_results[name])
    action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print(name, locations[name], global_time, action_results[name])
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)
    
    for name in people:
      for name_two in people:
        memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

  memory_ratings = {}
  for name in town_people.keys():
    memory_ratings[name] = []
    for i, memory in enumerate(memories[name]):
      prompt = "You are {}. Your plans are: {}. Your memories are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], '\n'.join(compressed_memories_all[name][-5:]), locations[name], str(global_time), memory)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      memory_ratings[name].append((res, rating))

  MEMORY_LIMIT = 10
  compressed_memories = {}
  for name in town_people.keys():
    memories_sorted = sorted(
          memory_ratings[name], 
          key=lambda x: x[1]
      )[::-1]
    relevant_memories = memories_sorted[:MEMORY_LIMIT]
    memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
    res = generate(prompt_meta.format(prompt))
    compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
    compressed_memories_all[name].append(compressed_memories[name])

  place_ratings = {}

  for name in town_people.keys():
    place_ratings[name] = []
    for area in town_areas.keys():
      prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      place_ratings[name].append((area, rating, res))
    place_ratings_sorted = sorted(
        place_ratings[name], 
        key=lambda x: x[1] )[::-1]
    if place_ratings_sorted[0][0] != locations[name]:
      new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
      compressed_memories_all[name].append(new_recollection)
    locations[name] = place_ratings_sorted[0][0]
# Out:
# Toblen Stonehill 10 I talked to Daran Edermath about my goals for the day, then headed to the market and made sure my customers got what they need.
# Daran Edermath 10 In the next hour, I explored Tresendar Manor and did my best to find the Redbrands hidden hideout. I also make sure not to get caught in the Redbrands traps. I chatted with my friends and do my best to find out who is in the manor. If I cant find anyone, I also may join in on a conversation with Toblen Stonehill to get to the Redbrands hideout.
# Linene Graywind 10 Linene had lunch at 11:30.
# Halia Thornton 10 I looked for new sources of supplies for my trading post.
# Qelline Alderleaf 10 Qelloi went into Townmaster’s Hall to see what was going on.
# Sister Garaele 10 I spent time with Linene and Sister Garaele to further explore Alderleaf Farm.
# Harbin Wester 10 I plan on having a drink with Harbin Wester and meeting other people who have been unable to make it into town yet, so we can discuss potential projects and brainstorm ideas.
# Terrill Five Fingers 10 Terrill: Hello. Is there anything I can help you with? Terrill: Yes, Im looking for food. Anything you have on hand? Terrill: No, thanks. I was looking for something else. Do you think you know any good restaurants near here? Terrill: Yes, I had come across these Italian restaurants. I had heard they were excellent. The owner was a young, attractive woman, and she greeted me quickly, asking if I was looking for anything in particular. I said, Im looking for something to eat. She said, I dont think I have anything specific in mind. Are you looking for anything in particular?
# Conrad Scarface 10 I spent time exploring and observing the environment in the next hour.
# Robbing Nellie 10 I planned to rob Nellie at 11:30.
# Valerie the Grin 10 I will likely rob a few people in the village, have lunch, then kill an adventurer.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-80049ca312b2> in <cell line: 1>()
#      43     for i, memory in enumerate(memories[name]):
#      44       prompt = "You are {}. Your plans are: {}. Your memories are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], '\n'.join(compressed_memories_all[name][-5:]), locations[name], str(global_time), memory)
# ---> 45       res = generate(prompt_meta.format(prompt))
#      46       rating = get_rating(res)
#      47       max_attempts = 2
#
# <ipython-input-3-b1f82efcaf62> in generate(prompt)
#       6 ### Response:'''
#       7 def generate(prompt):
# ----> 8   output = model(prompt, do_sample=True, min_length=10, max_length=len(prompt)+128)
#       9   out = output[0]['generated_text']
#      10   if '### Response:' in out:
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     163         """
#     164
# --> 165         result = super().__call__(*args, **kwargs)
#     166         if (
#     167             isinstance(args[0], list)
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1107             )
#    1108         else:
# -> 1109             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1110
#    1111     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1114     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1115         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1116         model_outputs = self.forward(model_inputs, **forward_params)
#    1117         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1118         return outputs
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1013                 with inference_context():
#    1014                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1015                     model_outputs = self._forward(model_inputs, **forward_params)
#    1016                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1017             else:
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/text2text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     185         generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     186         self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 187         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     188         out_b = output_ids.shape[0]
#     189         if self.framework == "pt":
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, **kwargs)
#    1450
#    1451             # 13. run sample
# -> 1452             return self.sample(
#    1453                 input_ids,
#    1454                 logits_processor=logits_processor,
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2466
#    2467             # forward pass to get next token
# -> 2468             outputs = self(
#    2469                 **model_inputs,
#    2470                 return_dict=True,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1702
#    1703         # Decode
# -> 1704         decoder_outputs = self.decoder(
#    1705             input_ids=decoder_input_ids,
#    1706             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1072                 )
#    1073             else:
# -> 1074                 layer_outputs = layer_module(
#    1075                     hidden_states,
#    1076                     attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     717                 query_length = None
#     718
# --> 719             cross_attention_outputs = self.layer[1](
#     720                 hidden_states,
#     721                 key_value_states=encoder_hidden_states,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     632     ):
#     633         normed_hidden_states = self.layer_norm(hidden_states)
# --> 634         attention_output = self.EncDecAttention(
#     635             normed_hidden_states,
#     636             mask=attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     557             position_bias_masked = position_bias
#     558
# --> 559         scores += position_bias_masked
#     560         attn_weights = nn.functional.softmax(scores.float(), dim=-1).type_as(
#     561             scores
#
# KeyboardInterrupt:
